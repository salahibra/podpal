# %%
import pandas as pd

# %%
# load data from json file
df = pd.read_json("C:\\Users\\SALAH\\Desktop\\podpal\\podcast_dataset\\podcast_epds_dataset.json")
df
# Out:
#        podcast_id                  podcast_title  \
# 0         5808875                Startup Insider
# 1         5808875                Startup Insider
# 2         5808875                Startup Insider
# 3         5808875                Startup Insider
# 4         5808875                Startup Insider
# ...           ...                            ...
# 10230     3831279  Teach. Travel. Talk About It.
# 10231     3831279  Teach. Travel. Talk About It.
# 10232     3831279  Teach. Travel. Talk About It.
# 10233     3831279  Teach. Travel. Talk About It.
# 10234     3831279  Teach. Travel. Talk About It.
#
#                                      podcast_description   episode_id  \
# 0      Der Startup Insider Podcast ist ein Muss für a...  37980484481
# 1      Der Startup Insider Podcast ist ein Muss für a...  37947585629
# 2      Der Startup Insider Podcast ist ein Muss für a...  37931308352
# 3      Der Startup Insider Podcast ist ein Muss für a...  37926223684
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10235 entries, 0 to 10234
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   podcast_id           10235 non-null  int64
#  1   podcast_title        10235 non-null  object
#  2   podcast_description  10235 non-null  object
#  3   episode_id           10235 non-null  int64
#  4   episode_title        10235 non-null  object
#  5   episode_description  10235 non-null  object
#  6   episode_link         10235 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 559.9+ KB

# %%
# duplicated episodes
sub = ["podcast_title","episode_title", "episode_link"]
data = df[df.duplicated(sub)==True]
data
# Out:
#       podcast_id                       podcast_title  \
# 1890      563298          Mental Health In Minnesota
# 4047     1002674       Biological Farming Roundtable
# 4049     1002674       Biological Farming Roundtable
# 6814      437920  Book Chat W/Author Vivian E. Moore
# 6815      437920  Book Chat W/Author Vivian E. Moore
# 6816      437920  Book Chat W/Author Vivian E. Moore
# 6817      437920  Book Chat W/Author Vivian E. Moore
# 6818      437920  Book Chat W/Author Vivian E. Moore
# 6819      437920  Book Chat W/Author Vivian E. Moore
# 6820      437920  Book Chat W/Author Vivian E. Moore
# 6821      437920  Book Chat W/Author Vivian E. Moore
# 6822      437920  Book Chat W/Author Vivian E. Moore
# 6823      437920  Book Chat W/Author Vivian E. Moore
# 7110      520183          The Effective Manager Book
# 7112      520183          The Effective Manager Book
# 7114      520183          The Effective Manager Book
#
# ...

# %%
n = 0
for v in df.values:
    if v in data.values:
        print(v)
        n+=1
print(n)
# Out:
# [563298 'Mental Health In Minnesota'
#  '"Mental Health In Minnesota" is a podcast produced by NAMI Minnesota and consists of interviews with NAMI Minnesota members, volunteers, staff members, board members, and advocates as they share their personal stories of hope and provide information about mental illnesses, treatment and mental health policies.\n\nNAMI Minnesota champions justice, dignity, and respect for all people affected by mental illnesses. Through education, support, and advocacy we strive to eliminate the pervasive stigma of mental illnesses, effect positive changes in the mental health system, and increase the public and professional understanding of mental illnesses.'
#  31483194862 'National Family Caregiver Day'
#  'In recognition of National Family Caregiver Day, this episode of\xa0Parent Perspectives\xa0sheds light on the unique and often underappreciated experiences of family caregivers supporting loved ones with mental health challenges. Hosted more »'
# ...

# %%
# print duplicate rows
duplicates = df[df.duplicated()]

# %%
print("Duplicate rows:")
print(duplicates)
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [podcast_id, podcast_title, podcast_description, episode_id, episode_title, episode_description, episode_link]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10235 entries, 0 to 10234
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   podcast_id           10235 non-null  int64
#  1   podcast_title        10235 non-null  object
#  2   podcast_description  10235 non-null  object
#  3   episode_id           10235 non-null  int64
#  4   episode_title        10235 non-null  object
#  5   episode_description  10235 non-null  object
#  6   episode_link         10235 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 559.9+ KB

# %%
df.drop_duplicates(subset=["podcast_title", "podcast_description","episode_title", "episode_description","episode_link"], inplace=True)
print("After removing duplicates:")
print(df.info())
# Out:
# After removing duplicates:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10220 entries, 0 to 10234
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   podcast_id           10220 non-null  int64
#  1   podcast_title        10220 non-null  object
#  2   podcast_description  10220 non-null  object
#  3   episode_id           10220 non-null  int64
#  4   episode_title        10220 non-null  object
#  5   episode_description  10220 non-null  object
#  6   episode_link         10220 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 638.8+ KB
# None
